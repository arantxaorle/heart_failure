# %%
pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for collections2: filename=collections2-0.3.0-py3-none-any.whl size=5334 sha256=fa6b708984e98ebd45597fbc2151aff4b0864a69f9835c1c6c56647096f7d376
#   Stored in directory: c:\users\arant\appdata\local\pip\cache\wheels\d8\3b\8c\dadea04c9bcf6850d1b411d2de3fb74c7875d0272ede34cad3
# Successfully built collections2
# ...
# Note: you may need to restart the kernel to use updated packages.
